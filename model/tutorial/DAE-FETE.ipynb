# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib notebook

# %%
col = ['frame','pre_num','pre_oflow','pre_v','cur_num','cur_inflow','cur_v']
data_1951 = pd.read_csv('../../data/small/sample/1951_node_sample.txt',delim_whitespace=True,names=col)
data_1951 =data_1951.dropna()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-698fa3d8650c> in <module>()
#       1 col = ['frame','pre_num','pre_oflow','pre_v','cur_num','cur_inflow','cur_v']
# ----> 2 data_1951 = pd.read_csv('../../data/small/sample/1951_node_sample.txt',delim_whitespace=True,names=col)
#       3 data_1951 =data_1951.dropna()
#
# ...

# %%
sns.distplot(data_1951.cur_inflow[data_1951.cur_inflow.notnull()])
#data_1951.cur_inflow.describe()
#data_1951.cur_inflow.notnull()

# %%
sns.set()
cols = ['cur_inflow','pre_num','pre_v','cur_num','cur_v']
sns.pairplot(data_1951[cols], size = 2.5)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="1250">
